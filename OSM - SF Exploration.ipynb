# %% [markdown]
# # Data Wrangling the OpenStreetMap: San Francisco
#
# _An exercise in auditing, cleaning, and exploring the City of San Francisco's OpenStreetMap (OSM) data provided by the [OpenStreetMap Project](https://www.openstreetmap.org/relation/111968)._
#
# **Ravi Dayabhai**

# %%
# Import dependencies
import xml.etree.cElementTree as ET
import pprint
import re
from collections import defaultdict
import sqlite3
import pandas as pd
import math
import folium
from pyzipcode import ZipCodeDatabase
import numpy as np
import os


# Initialize PrettyPrinter object
pp = pprint.PrettyPrinter()

# %% [markdown]
# ## Introduction
#
# I chose San Francisco as the map area to explore because I am relatively new to the area having lived the entirety of my adult life on the east coast. I figured using the following map extract to complete this project would also give me a better sense of my new home city!
#
# >**NOTE**: _Cleaning_, for the purposes of this project, simply means that various tags were standardized (according to convention of my choosing) before being exported to tables (and, subsequently, read into a SQLite database). More on this later in this project document.
#
# **Map Area**
# - [San Francisco](https://www.openstreetmap.org/relation/111968); custom extract for the _City of San Francisco_ rather than the entire bay area or outlying islands.
#
# **Files**
# - `audit.py`
#  - This script houses the functions used by `data.py` to clean the OSM file.
# - `data.py`
#  - This is the script (skeleton provided by the Case Study quiz) that parsed the OSM file and generated the CSV flatfiles according to the schema outlined in `schema.sql` (i.e., the prescribed schema provided by Udacity)
# - `database.py`
#  - This is a script I wrote to load all of the CSVs generated by `data.py` into a SQLite database according to the schema outlined in `schema.sql`.
# - `SF_OSM.db`
#     - The SQLite database housing the _cleaned_ information and which I query later on in the project.
#       - **NOTE**: This repo houses only a _sample_ of the map extract (due to file size limits and submission requirements).
# - `schema.sql`
#  - The schema suggested by Udacity for the SQLite database.

# %% [markdown]
# Here's a quick preview of the particular map area in question:
#
# ![City of San Francisco](map_extract_screenshot.png "SF Map Extract")

# %% [markdown]
# ### Overview

# %% [markdown]
# #### Size of Database
#
# The final, cleaned database size (vs. original OSM file) is calculated below:

# %%
database_size = os.path.getsize('./SF_OSM.db') / 1000000
osm_size = os.path.getsize('./SF_extract.osm') / 1000000

print("The size of the database is: %s MB" %round(database_size, 2))
print("The size of the OSM file is: %s MB" %round(osm_size, 2))
# Out:
# The size of the database is: 189.0 MB
# The size of the OSM file is: 359.0 MB

# %% [markdown]
# #### Tables
#
# The following command (`ANALYZE`) creates a summary of the table of the database, which I'm outputting to a Pandas DataFrame for ease of viewing.

# %%
# Set up database environment
conn = sqlite3.connect('SF_OSM.db')
c = conn.cursor()

# Turn off row limit
pd.set_option("display.max_rows",None)

# Turn off row limit
pd.set_option("display.max_columns",None)

for row in c.execute('ANALYZE;'):
    print row
    
stat_query = '''
SELECT tbl AS "Table", stat AS "Total Rows" FROM sqlite_stat1;
'''

# Query to Pandas DataFrame
df_db_stats = pd.read_sql_query(stat_query, conn)
df_db_stats
# Out:
#         Table Total Rows
# 0  ways_nodes    2103139
# 1   ways_tags     479392
# 2        ways     177567
# 3  nodes_tags     114601
# 4       nodes    1681560

# %% [markdown]
# This isn't the last time you'll see the database API interface! More to come on that below in the following sections:
#  - _Confirming Cleaned Data_
#  - _Exploring the Data_

# %% [markdown]
# ## Auditing

# %% [markdown]
# First, I took a look at the various kinds of `tag` tags present in the OSM file:

# %%
# Figures out what tag types there are for nodes and ways
def tag_checker():

    # Initialize variables
    node_types = set()
    way_types = set()
    
    # Loop through all top level tags
    for event, elem in ET.iterparse(osm_data, events=("start",)):

        # 'node' tags
        if elem.tag == "node":
            for tag in elem.iter("tag"):
                atrbt = tag.attrib["k"]
                node_types.add(atrbt)

        # 'way' tags
        if elem.tag == "way":
            for tag in elem.iter("tag"):
                atrbt = tag.attrib["k"]
                way_types.add(atrbt)
    
    return {"Nodes": node_types, "Ways": way_types}

with open("SF_extract.osm", "r") as osm_data:
    tag_types = tag_checker()
    
pp.pprint(tag_types)
# Out:
# {'Nodes': set(['FIXME',
#                'Id',
#                'Keyword',
#                'Sign Legen',
#                'Street Fro',
#                'Street Ont',
#                'Subclass',
#                'Trunk_Diam',
#                'access',
#                'addr.source:housenumber',
#                'addr:city',
#                'addr:country',
#                'addr:door',
#                'addr:flats',
#                'addr:floor',
#                'addr:full',
#                'addr:housename',
#                'addr:housenumber',
#                'addr:housenumber:source',
#                'addr:pier',
#                'addr:place',
#                'addr:postcode',
#                'addr:source:housenumber',
#                'addr:state',
#                'addr:street',
#                'addr:suite',
#                'addr:unit',
#                'address',
#                'advertising',
#                'aeroway',
#                'alt_name',
#                'alt_name_1',
#                'alterations',
#                'amenity',
#                'amenity:disused',
#                'amenity_1',
#                'amtrak_drop_off_only',
#                'animal_shelter',
#                'animal_shelter:adoption',
#                'artist',
#                'artist_name',
#                'artwork',
#                'artwork_type',
#                'atm',
#                'atm:network',
#                'atm:operator',
#                'atm_inside',
#                'attraction',
#                'attribution',
#                'automated',
#                'baby',
#                'backrest',
#                'barrier',
#                'basketball',
#                'bearing',
#                'bench',
#                'bicycle',
#                'bicycle_parking',
#                'bin',
#                'blind:description:en',
#                'board_type',
#                'bollard',
#                'books',
#                'bottle',
#                'boxes',
#                'brand',
#                'brand:wikidata',
#                'bubbler',
#                'building',
#                'building:levels',
#                'building:levels:underground',
#                'building:material',
#                'bulb',
#                'bus',
#                'cable_car',
#                'cafe',
#                'camera:mount',
#                'camera:type',
#                'capacity',
#                'car_wash',
#                'cargo',
#                'cash_in',
#                'category',
#                'census:population',
#                'climbing',
#                'clothes',
#                'club',
#                'coffee',
#                'coin:design_count',
#                'coin:type',
#                'coin_op',
#                'collection_times',
#                'colour',
#                'comedy',
#                'common',
#                'construction',
#                'contact:atom',
#                'contact:email',
#                'contact:facebook',
#                'contact:fax',
#                'contact:google_plus',
#                'contact:instagram',
#                'contact:myspace',
#                'contact:phone',
#                'contact:rss',
#                'contact:website',
#                'contact:yelp',
#                'content',
#                'control',
#                'cooperative',
#                'cost:coffee',
#                'country',
#                'covered',
#                'craft',
#                'created_by',
#                'crossing',
#                'crossing_ref',
#                'cuisine',
#                'cuisine_1',
#                'currency:USD',
#                'cycleway',
#                'dance:teaching',
#                'date',
#                'delivery',
#                'demolished',
#                'demolished:amenity',
#                'denomination',
#                'depository',
#                'depth',
#                'description',
#                'description:en',
#                'designation',
#                'designer',
#                'diaper',
#                'diaper:unisex',
#                'diet:gluten_free',
#                'diet:halal',
#                'diet:lactose_free',
#                'diet:vegan',
#                'diet:vegetarian',
#                'diplomatic',
#                'direction',
#                'dispensing',
#                'display',
#                'disused',
#                'disused:amenity',
#                'disused:brand:wikidata',
#                'disused:cuisine',
#                'disused:highway',
#                'disused:office',
#                'disused:railway',
#                'disused:shop',
#                'disused:website',
#                'disused:wheelchair',
#                'dog',
#                'drink:juice',
#                'drinking_water',
#                'drive_in',
#                'drive_through',
#                'drive_through_atm',
#                'drop_off_only',
#                'dry_clean',
#                'ele',
#                'elevator',
#                'email',
#                'emergency',
#                'emergency:note',
#                'emergency:notes',
#                'entrance',
#                'escalator',
#                'established',
#                'ethnicity',
#                'event',
#                'exit',
#                'exit_to',
#                'exit_to:left',
#                'exit_to:right',
#                'facebook',
#                'fax',
#                'fee',
#                'female',
#                'finished_laundry',
#                'fire_hydrant:position',
#                'fire_hydrant:type',
#                'fixme',
#                'food',
#                'foot',
#                'ford',
#                'fuel',
#                'fuel:biodiesel',
#                'fuel:diesel',
#                'fuel:kerosene',
#                'fuel:unleaded',
#                'furniture',
#                'garage',
#                'generator:source',
#                'ggt_drop_off_only',
#                'ggt_route_ref',
#                'gluten_free',
#                'gnis:Class',
#                'gnis:County',
#                'gnis:County_num',
#                'gnis:ST_alpha',
#                'gnis:ST_num',
#                'gnis:county_id',
#                'gnis:county_name',
#                'gnis:created',
#                'gnis:edited',
#                'gnis:feature_id',
#                'gnis:feature_type',
#                'gnis:id',
#                'gnis:import_uuid',
#                'gnis:reviewed',
#                'gnis:state_id',
#                'guidepost',
#                'happy_hour',
#                'has_outside_atm',
#                'has_vestibule_atm',
#                'hazard',
#                'health_facility:type',
#                'health_specialty:physiotherapy',
#                'health_specialty:speech_therapy',
#                'healthcare',
#                'healthcare:speciality',
#                'height',
#                'heritage',
#                'heritage:operator',
#                'highway',
#                'highway:disused',
#                'historic',
#                'historic:amenity',
#                'image',
#                'import_uuid',
#                'indoor',
#                'indoor_seating',
#                'information',
#                'inside',
#                'inside_at_operator',
#                'inside_atm',
#                'inside_atm_capacity',
#                'inside_atm_op',
#                'internet_access',
#                'internet_access:fee',
#                'is_in',
#                'is_in:continent',
#                'is_in:country',
#                'is_in:country_code',
#                'island',
#                'lamp_type',
#                'landuse',
#                'language:en',
#                'laundry_service',
#                'layer',
#                'leaf_cycle',
#                'leaf_type',
#                'leisure',
#                'leisure_1',
#                'level',
#                'levels',
#                'lit',
#                'live_music',
#                'local_ref',
#                'location',
#                'male',
#                'man_made',
#                'manager',
#                'map',
#                'map_size',
#                'map_type',
#                'material',
#                'maxlength',
#                'maxspeed',
#                'maxwidth',
#                'memorial',
#                'microbrewery',
#                'military',
#                'monitoring:bicycle',
#                'monitoring:weather',
#                'motor_vehicle',
#                'motorcar',
#                'motorcycle',
#                'motorcycle:rental',
#                'motorcycle:repair',
#                'muni_route_ref',
#                'name',
#                'name:ca',
#                'name:cs',
#                'name:de',
#                'name:en',
#                'name:es',
#                'name:eu',
#                'name:fa',
#                'name:fr',
#                'name:he',
#                'name:hi',
#                'name:it',
#                'name:ja',
#                'name:kn',
#                'name:ko',
#                'name:lt',
#                'name:pt',
#                'name:ru',
#                'name:ta',
#                'name:tt',
#                'name:uk',
#                'name:zh',
#                'name_1',
#                'name_2',
#                'name_alt',
#                'natural',
#                'natural_1',
#                'network',
#                'network:wikidata',
#                'newaesthetic',
#                'nextbus',
#                'nextbus:agency',
#                'nextbus:stopid',
#                'noaa:geohash',
#                'noaa:lnam',
#                'noaa:taghash',
#                'noexit',
#                'noref',
#                'note',
#                'nudism',
#                'num_row',
#                'office',
#                'official_name',
#                'old_amenity',
#                'old_man_made',
#                'old_name',
#                'old_name:en',
#                'old_name:hi',
#                'old_name:ja',
#                'old_name:kn',
#                'old_name:ta',
#                'old_tourism',
#                'onestop_id',
#                'opening_hours',
#                'opening_hours:url',
#                'oper',
#                'operator',
#                'operator:type',
#                'operator:wikidata',
#                'operator_2',
#                'organic',
#                'origin',
#                'outdoor',
#                'outdoor_seating',
#                'outerspatial:id',
#                'outside',
#                'outside_atm',
#                'outside_atm_capacity',
#                'outside_atm_operator',
#                'park_ride',
#                'parking',
#                'payment:bitcoin',
#                'payment:cash',
#                'payment:coins',
#                'payment:credit_cards',
#                'payment:debit_cards',
#                'payment:discover_card',
#                'payment:dogecoin',
#                'payment:litecoin',
#                'payment:mastercard',
#                'payment:none',
#                'payment:peercoin',
#                'payment:vertcoin',
#                'payment:visa',
#                'phone',
#                'pizza',
#                'place',
#                'playground',
#                'population',
#                'population:date',
#                'post_office:type',
#                'postal_code',
#                'power',
#                'public',
#                'public_transport',
#                'pupuseria',
#                'quantity',
#                'railway',
#                'ramp',
#                'ramp:wheelchair',
#                'rank',
#                'recycling:cans',
#                'recycling:glass_bottles',
#                'recycling:plastic_bottles',
#                'recycling_type',
#                'ref',
#                'ref:BART',
#                'ref:clipper:machine',
#                'ref:clipper:terminal',
#                'ref:left',
#                'ref:nrhp',
#                'ref:right',
#                'ref:sfdl',
#                'religion',
#                'rental',
#                'repair',
#                'reviewed',
#                'rooms',
#                'route_ref',
#                'samtrans_drop_off_only',
#                'samtrans_route_ref',
#                'sanitary_dump_station:pump-out',
#                'seamark:beacon_lateral:category',
#                'seamark:beacon_lateral:colour',
#                'seamark:beacon_lateral:reflectivity',
#                'seamark:beacon_lateral:shape',
#                'seamark:beacon_safe_water:shape',
#                'seamark:beacon_special_purpose:category',
#                'seamark:beacon_special_purpose:colour',
#                'seamark:beacon_special_purpose:reflectivity',
#                'seamark:beacon_special_purpose:shape',
#                'seamark:buoy_lateral:category',
#                'seamark:buoy_lateral:colour',
#                'seamark:buoy_lateral:colour_pattern',
#                'seamark:buoy_lateral:shape',
#                'seamark:buoy_special_purpose:colour',
#                'seamark:buoy_special_purpose:shape',
#                'seamark:daymark:colour',
#                'seamark:daymark:colour_pattern',
#                'seamark:daymark:construction',
#                'seamark:daymark:shape',
#                'seamark:fog_signal:category',
#                'seamark:fog_signal:generation',
#                'seamark:fog_signal:group',
#                'seamark:fog_signal:period',
#                'seamark:fog_signal:sequence',
#                'seamark:information',
#                'seamark:landmark:conspicuity',
#                'seamark:light:category',
#                'seamark:light:character',
#                'seamark:light:colour',
#                'seamark:light:exhibition',
#                'seamark:light:group',
#                'seamark:light:height',
#                'seamark:light:period',
#                'seamark:light:range',
#                'seamark:light:sequence',
#                'seamark:name',
#                'seamark:source',
#                'seamark:status',
#                'seamark:type',
#                'second_hand',
#                'self_service',
#                'service',
#                'service area',
#                'service:bicycle:chain_tool',
#                'service:bicycle:dealer',
#                'service:bicycle:diy',
#                'service:bicycle:parts',
#                'service:bicycle:pump',
#                'service:bicycle:rental',
#                'service:bicycle:repair',
#                'service:bicycle:retail',
#                'service:bicycle:second_hand',
#                'service:press',
#                'service_times',
#                'sfgov.org:OBJECTID',
#                'sfgov.org:OFFICE_TYP',
#                'shelter',
#                'shelter_type',
#                'shop',
#                'shop_1',
#                'short_name',
#                'site',
#                'sloped_curb',
#                'smoking',
#                'social_facility',
#                'social_facility:for',
#                'source',
#                'source:pkey',
#                'source_ref',
#                'species:en',
#                'speech_output:en',
#                'sport',
#                'stairs',
#                'stars',
#                'start_date',
#                'stateofrepair',
#                'station_name',
#                'stop',
#                'stop_id',
#                'street',
#                'studio',
#                'subway',
#                'supervised',
#                'support',
#                'surveillance',
#                'surveillance:type',
#                'survey:date',
#                'tactile_paving',
#                'takeaway',
#                'taqueria',
#                'taxon',
#                'terminal',
#                'terrace',
#                'ticker',
#                'tickets',
#                'toilets',
#                'toilets:disposal',
#                'toilets:opening_hours',
#                'toilets:position',
#                'toilets:wheelchair',
#                'tourism',
#                'tourism_2',
#                'tower:type',
#                'trade',
#                'traffic_calming',
#                'traffic_sign',
#                'traffic_signals',
#                'traffic_signals:sound',
#                'train',
#                'training',
#                'tram',
#                'trolley_wire',
#                'trolleybus',
#                'turn_restrictions',
#                'type',
#                'undefined',
#                'unisex',
#                'unmarked',
#                'url',
#                'usage',
#                'vending',
#                'vendor_model',
#                'verified',
#                'vestibule_atm',
#                'vestibule_atm_capacity',
#                'vestibule_atm_fee',
#                'vestibule_atm_op',
#                'vestibule_atm_operator',
#                'vestibule_depository',
#                'visibility',
#                'water',
#                'waterway',
#                'website',
#                'wetap:bottle',
#                'wetap:photo',
#                'wetap:status',
#                'wetap:statusnote',
#                'wheelchair',
#                'wheelchair:description',
#                'wifi',
#                'wikidata',
#                'wikipedia',
#                'wine',
#                'wpt_description',
#                'yelp',
#                'z_order']),
#  'Ways': set(['ALAND',
#               'AREAID',
#               'AREA_M2',
#               'AWATER',
#               'BLDGID',
#               'CATEGORY',
#               'CITY_OWNED',
#               'DEPT',
#               'FIXME',
#               'FMMP_modified',
#               'FMMP_reviewed',
#               'LAND_ID',
#               'LAND_NAME',
#               'MTFCC',
#               'NHS',
#               'OBJECTID',
#               'OBJNAME',
#               'Stevenson Place',
#               'Tiger:MTFCC',
#               'abandoned:amenity',
#               'abandoned:name',
#               'abandoned:shop',
#               'access',
#               'access:backward',
#               'access:conditional',
#               'access:lanes',
#               'access:lanes:both_ways',
#               'acres',
#               'addr.source:housenumber',
#               'addr:city',
#               'addr:country',
#               'addr:county',
#               'addr:full',
#               'addr:housename',
#               'addr:housenumber',
#               'addr:housenumber:source',
#               'addr:interpolation',
#               'addr:postcode',
#               'addr:source:housenumber',
#               'addr:state',
#               'addr:street',
#               'addr:street:source',
#               'addr:unit',
#               'address',
#               'admin_level',
#               'aeroway',
#               'alt_name',
#               'alt_name2',
#               'alt_name_1',
#               'alt_url',
#               'amenity',
#               'animal_boarding',
#               'animal_shelter',
#               'animal_shelter:adoption',
#               'architect',
#               'area',
#               'area:highway',
#               'area:railway',
#               'artist',
#               'artist_name',
#               'artwork_type',
#               'atm',
#               'attraction',
#               'attribution',
#               'baby_hatch',
#               'backrest',
#               'barrier',
#               'bicycle',
#               'bicycle:designated',
#               'bicycle_parking',
#               'boat',
#               'border_type',
#               'boundary',
#               'brand',
#               'brand:wikidata',
#               'bridge',
#               'bridge:alt_name',
#               'bridge:movable',
#               'bridge:name',
#               'bridge:old_name',
#               'bridge:structure',
#               'bridge:support',
#               'building',
#               'building.source:levels',
#               'building:colour',
#               'building:height',
#               'building:level',
#               'building:levels',
#               'building:levels:underground',
#               'building:material',
#               'building:min_level',
#               'building:number',
#               'building:part',
#               'building:ref',
#               'building:shape',
#               'building:use',
#               'bunker_type',
#               'bus',
#               'bus:lanes',
#               'bus:lanes:backward',
#               'bus:lanes:forward',
#               'cable_car',
#               'cables',
#               'caltrans:district',
#               'caltrans:dynsegpm',
#               'caltrans:type',
#               'capacity',
#               'capacity:disabled',
#               'car',
#               'cargo',
#               'change:backward',
#               'change:forward',
#               'change:lanes',
#               'change:lanes:backward',
#               'change:lanes:forward',
#               'climbing',
#               'climbing:grade:yds_class',
#               'clothes',
#               'collection_times',
#               'colour',
#               'comment',
#               'community',
#               'community:en',
#               'community:gender',
#               'construction',
#               'contact:email',
#               'contact:fax',
#               'contact:phone',
#               'contact:website',
#               'conveying',
#               'cooperative',
#               'country',
#               'courts',
#               'covered',
#               'craft',
#               'created_by',
#               'crossing',
#               'csp:globalid',
#               'csp:unitcode',
#               'cuisine',
#               'cutting',
#               'cycleway',
#               'cycleway:buffer',
#               'cycleway:left',
#               'cycleway:right',
#               'dance:teaching',
#               'day_off',
#               'day_on',
#               'delivery',
#               'demolished',
#               'denomination',
#               'depository',
#               'description',
#               'description:zh',
#               'designation',
#               'destination',
#               'destination:lanes',
#               'destination:name',
#               'destination:ref',
#               'destination:ref:lanes',
#               'destination:ref:to',
#               'destination:street',
#               'diaper',
#               'diet:halal',
#               'diplomatic',
#               'diplomatic:sending_country',
#               'direction',
#               'dispensing',
#               'disused',
#               'disused:amenity',
#               'disused:building',
#               'disused:highway',
#               'disused:office',
#               'disused:railway',
#               'disused:shop',
#               'dog',
#               'drinking_water',
#               'drive_through',
#               'drive_through_atm',
#               'drive_through_atm_capacity',
#               'ele',
#               'electrified',
#               'elevation',
#               'email',
#               'emergency',
#               'emergency:note',
#               'end_date',
#               'entrance',
#               'fax',
#               'fee',
#               'female',
#               'fence_type',
#               'fenced',
#               'field_marking',
#               'fixme',
#               'foot',
#               'footway',
#               'former_name',
#               'frequency',
#               'fuel',
#               'fuel:octane_91',
#               'garden:type',
#               'gauge',
#               'generator:source',
#               'gnis:Class',
#               'gnis:County',
#               'gnis:County_num',
#               'gnis:ST_alpha',
#               'gnis:ST_num',
#               'gnis:county_id',
#               'gnis:county_name',
#               'gnis:created',
#               'gnis:edited',
#               'gnis:feature_id',
#               'gnis:id',
#               'gnis:import_uuid',
#               'gnis:reviewed',
#               'gnis:state_id',
#               'golf',
#               'gosm:sig:8CBDE645',
#               'grade',
#               'grades',
#               'half_court',
#               'handicap',
#               'handrail',
#               'handrail:center',
#               'handrail:left',
#               'handrail:right',
#               'hazard',
#               'hazard:bicycle',
#               'healthcare',
#               'height',
#               'heritage',
#               'heritage:operator',
#               'hgv',
#               'hgv:national_network',
#               'hgv:state_network',
#               'highway',
#               'hist_name',
#               'historic',
#               'historic:name',
#               'history',
#               'hoops',
#               'horse',
#               'hov',
#               'image',
#               'import_uuid',
#               'incline',
#               'indoor',
#               'informal',
#               'inner',
#               'internet_access',
#               'internet_access:fee',
#               'internet_access:ssid',
#               'is_in',
#               'junction',
#               'junction:ref',
#               'kerb',
#               'landcover',
#               'landuse',
#               'landuse_1',
#               'landuse_2',
#               'landuse_3',
#               'lanes',
#               'lanes:backward',
#               'lanes:both_ways',
#               'lanes:bus',
#               'lanes:forward',
#               'layer',
#               'lcn',
#               'lcn_ref',
#               'leaf_cycle',
#               'leaf_type',
#               'leisure',
#               'leisure_1',
#               'level',
#               'light_rail',
#               'lit',
#               'localwiki',
#               'location',
#               'male',
#               'man_made',
#               'mapillary',
#               'maxheight',
#               'maxspeed',
#               'maxspeed:advisory',
#               'maxspeed:hgv',
#               'maxspeed:trailer',
#               'maxstay',
#               'maxweight',
#               'microbrewery',
#               'military',
#               'min_height',
#               'motor_vehicle',
#               'motor_vehicle:conditional',
#               'motorcar',
#               'motorcycle',
#               'mown',
#               'museum',
#               'name',
#               'name:ar',
#               'name:da',
#               'name:de',
#               'name:en',
#               'name:es',
#               'name:fa',
#               'name:fr',
#               'name:he',
#               'name:it',
#               'name:ja',
#               'name:kn',
#               'name:ko',
#               'name:pa',
#               'name:pl',
#               'name:pt',
#               'name:ru',
#               'name:sv',
#               'name:zh',
#               'name_1',
#               'name_2',
#               'name_alt',
#               'name_base',
#               'name_type',
#               'natural',
#               'network',
#               'nhd:reach_code',
#               'noexit',
#               'noname',
#               'note',
#               'note:address',
#               'note:lanes',
#               'note:lcn',
#               'note:name',
#               'note:wheelchair',
#               'nudism',
#               'office',
#               'official_name',
#               'old_amenity',
#               'old_denomination',
#               'old_name',
#               'old_name_1',
#               'old_ref',
#               'old_religion',
#               'onestop_id',
#               'oneway',
#               'oneway:bicycle',
#               'oneway:psv',
#               'opening_hours',
#               'operator',
#               'operator:type',
#               'origin',
#               'outdoor_living_room',
#               'outdoor_seating',
#               'outside',
#               'outside_atm',
#               'outside_atm_capacity',
#               'outside_atm_op',
#               'outside_atm_operator',
#               'overtaking',
#               'owner',
#               'par',
#               'parapet',
#               'park',
#               'park:type',
#               'park_ride',
#               'parking',
#               'parking:condition:both',
#               'parking:condition:both:maxstay',
#               'parking:condition:both:residents',
#               'parking:condition:both:time_interval',
#               'parking:condition:left',
#               'parking:condition:left:2',
#               'parking:condition:left:2:reason',
#               'parking:condition:left:2:time_interval',
#               'parking:condition:left:maxstay',
#               'parking:condition:left:residents',
#               'parking:condition:left:time_interval',
#               'parking:condition:right',
#               'parking:condition:right:2',
#               'parking:condition:right:2:reason',
#               'parking:condition:right:2:time_interval',
#               'parking:condition:right:maxstay',
#               'parking:condition:right:residents',
#               'parking:condition:right:time_interval',
#               'parking:lane:both',
#               'parking:lane:left',
#               'parking:lane:right',
#               'parking_space',
#               'passenger',
#               'paved',
#               'payment:bitcoin',
#               'payment:litecoin',
#               'pedestrian',
#               'pedestrians',
#               'phone',
#               'place',
#               'placement',
#               'placement:backward',
#               'placement:forward',
#               'plant:output:electricity',
#               'platforms',
#               'playground',
#               'power',
#               'product',
#               'proposed',
#               'psv',
#               'psv:lanes',
#               'psv:lanes:backward',
#               'psv:lanes:forward',
#               'public',
#               'public_transport',
#               'quantity',
#               'railroad',
#               'railway',
#               'railway:lanes',
#               'railway:traffic_mode',
#               'ramp',
#               'ramp:bicycle',
#               'ramp:wheelchair',
#               'ref',
#               'ref:blklot',
#               'ref:nrhp',
#               'religion',
#               'rental',
#               'reviewed',
#               'roof:colour',
#               'roof:height',
#               'roof:material',
#               'roof:orientation',
#               'roof:shape',
#               'roof:slope:direction',
#               'route',
#               'sac_scale',
#               'seamark:name',
#               'seamark:type',
#               'second_hand',
#               'segregated',
#               'service',
#               'service:bicycle:pump',
#               'service:bicycle:rental',
#               'service:bicycle:repair',
#               'service:bicycle:retail',
#               'service:bicycle:second_hand',
#               'service:press',
#               'sfgov.org:OBJECTID',
#               'sfgov.org:OFFICE_TYP',
#               'sfgov:OBJNAME',
#               'shelter',
#               'ship:type',
#               'shop',
#               'short_name',
#               'sidewalk',
#               'slipway:type',
#               'smoking',
#               'smoothness',
#               'social_facility',
#               'social_facility:for',
#               'source',
#               'source:addr:housenumber',
#               'source:geometry',
#               'source:hgv:national_network',
#               'source:hgv:state_network',
#               'source:incline',
#               'source:maxspeed',
#               'source:name',
#               'source:pkey',
#               'species',
#               'sport',
#               'stairs',
#               'stars',
#               'start_date',
#               'station',
#               'station_id',
#               'step_count',
#               'steps',
#               'store_number',
#               'structure',
#               'substance',
#               'subway',
#               'supervised',
#               'surface',
#               'survey:date',
#               'tactile_paving',
#               'takeaway',
#               'taxi',
#               'telecom',
#               'terrace',
#               'theatre',
#               'theatre:genre',
#               'tiger:cfcc',
#               'tiger:county',
#               'tiger:name_base',
#               'tiger:name_base_1',
#               'tiger:name_base_2',
#               'tiger:name_direction_prefix',
#               'tiger:name_direction_suffix',
#               'tiger:name_type',
#               'tiger:name_type_1',
#               'tiger:reviewed',
#               'tiger:separated',
#               'tiger:source',
#               'tiger:tlid',
#               'tiger:upload_uuid',
#               'tiger:zip_right',
#               'todo',
#               'toilets',
#               'toilets:disposal',
#               'toilets:wheelchair',
#               'toll',
#               'tomb',
#               'tourism',
#               'tourism_1',
#               'tracktype',
#               'traction',
#               'traffic_calming',
#               'trail_visibility',
#               'train',
#               'tram',
#               'trolley_wire',
#               'tunnel',
#               'turn:forward',
#               'turn:lanes',
#               'turn:lanes:backward',
#               'turn:lanes:both_ways',
#               'turn:lanes:forward',
#               'type',
#               'url',
#               'usage',
#               'valet',
#               'vehicle',
#               'verified',
#               'voltage',
#               'water',
#               'waterway',
#               'website',
#               'wetland',
#               'wheelchair',
#               'wheelchair:description',
#               'wholesale',
#               'width',
#               'wifi',
#               'wikidata',
#               'wikipedia',
#               'wpt_description',
#               'zoo'])}

# %% [markdown]
# **Observation #1**: Here we see that `addr:source:housenumber`, `addr.source:housenumber`, `addr:housenumber:source` are all inconsistent ways of conveying the same information. There is also some inconsistency in `tag` key conventions around "alternate names" (e.g., `alt_name_1` vs. `alt_name2`)
#
# >**Note**: I chose to ignore `addr.source:housenumber` in the `shape_element` function, but standardizing tags is definitely a point of potential improvement!
#
# **Observation #2**: Also, there are some very odd `way` tags (e.g., `Stevenson Place`, [`FIXME`](http://wiki.openstreetmap.org/wiki/Key:fixme), etc.) some of which reflect the ever-evolving nature of the map.

# %%
# Looks at the commonly shared tag types
pp.pprint(tag_types["Nodes"] & tag_types["Ways"])
# Out:
# set(['FIXME',
#      'access',
#      'addr.source:housenumber',
#      'addr:city',
#      'addr:country',
#      'addr:full',
#      'addr:housename',
#      'addr:housenumber',
#      'addr:housenumber:source',
#      'addr:postcode',
#      'addr:source:housenumber',
#      'addr:state',
#      'addr:street',
#      'addr:unit',
#      'address',
#      'aeroway',
#      'alt_name',
#      'alt_name_1',
#      'amenity',
#      'animal_shelter',
#      'animal_shelter:adoption',
#      'artist',
#      'artist_name',
#      'artwork_type',
#      'atm',
#      'attraction',
#      'attribution',
#      'backrest',
#      'barrier',
#      'bicycle',
#      'bicycle_parking',
#      'brand',
#      'brand:wikidata',
#      'building',
#      'building:levels',
#      'building:levels:underground',
#      'building:material',
#      'bus',
#      'cable_car',
#      'capacity',
#      'cargo',
#      'climbing',
#      'clothes',
#      'collection_times',
#      'colour',
#      'construction',
#      'contact:email',
#      'contact:fax',
#      'contact:phone',
#      'contact:website',
#      'cooperative',
#      'country',
#      'covered',
#      'craft',
#      'created_by',
#      'crossing',
#      'cuisine',
#      'cycleway',
#      'dance:teaching',
#      'delivery',
#      'demolished',
#      'denomination',
#      'depository',
#      'description',
#      'designation',
#      'diaper',
#      'diet:halal',
#      'diplomatic',
#      'direction',
#      'dispensing',
#      'disused',
#      'disused:amenity',
#      'disused:highway',
#      'disused:office',
#      'disused:railway',
#      'disused:shop',
#      'dog',
#      'drinking_water',
#      'drive_through',
#      'drive_through_atm',
#      'ele',
#      'email',
#      'emergency',
#      'emergency:note',
#      'entrance',
#      'fax',
#      'fee',
#      'female',
#      'fixme',
#      'foot',
#      'fuel',
#      'generator:source',
#      'gnis:Class',
#      'gnis:County',
#      'gnis:County_num',
#      'gnis:ST_alpha',
#      'gnis:ST_num',
#      'gnis:county_id',
#      'gnis:county_name',
#      'gnis:created',
#      'gnis:edited',
#      'gnis:feature_id',
#      'gnis:id',
#      'gnis:import_uuid',
#      'gnis:reviewed',
#      'gnis:state_id',
#      'hazard',
#      'healthcare',
#      'height',
#      'heritage',
#      'heritage:operator',
#      'highway',
#      'historic',
#      'image',
#      'import_uuid',
#      'indoor',
#      'internet_access',
#      'internet_access:fee',
#      'is_in',
#      'landuse',
#      'layer',
#      'leaf_cycle',
#      'leaf_type',
#      'leisure',
#      'leisure_1',
#      'level',
#      'lit',
#      'location',
#      'male',
#      'man_made',
#      'maxspeed',
#      'microbrewery',
#      'military',
#      'motor_vehicle',
#      'motorcar',
#      'motorcycle',
#      'name',
#      'name:de',
#      'name:en',
#      'name:es',
#      'name:fa',
#      'name:fr',
#      'name:he',
#      'name:it',
#      'name:ja',
#      'name:kn',
#      'name:ko',
#      'name:pt',
#      'name:ru',
#      'name:zh',
#      'name_1',
#      'name_2',
#      'name_alt',
#      'natural',
#      'network',
#      'noexit',
#      'note',
#      'nudism',
#      'office',
#      'official_name',
#      'old_amenity',
#      'old_name',
#      'onestop_id',
#      'opening_hours',
#      'operator',
#      'operator:type',
#      'origin',
#      'outdoor_seating',
#      'outside',
#      'outside_atm',
#      'outside_atm_capacity',
#      'outside_atm_operator',
#      'park_ride',
#      'parking',
#      'payment:bitcoin',
#      'payment:litecoin',
#      'phone',
#      'place',
#      'playground',
#      'power',
#      'public',
#      'public_transport',
#      'quantity',
#      'railway',
#      'ramp',
#      'ramp:wheelchair',
#      'ref',
#      'ref:nrhp',
#      'religion',
#      'rental',
#      'reviewed',
#      'seamark:name',
#      'seamark:type',
#      'second_hand',
#      'service',
#      'service:bicycle:pump',
#      'service:bicycle:rental',
#      'service:bicycle:repair',
#      'service:bicycle:retail',
#      'service:bicycle:second_hand',
#      'service:press',
#      'sfgov.org:OBJECTID',
#      'sfgov.org:OFFICE_TYP',
#      'shelter',
#      'shop',
#      'short_name',
#      'smoking',
#      'social_facility',
#      'social_facility:for',
#      'source',
#      'source:pkey',
#      'sport',
#      'stairs',
#      'stars',
#      'start_date',
#      'subway',
#      'supervised',
#      'survey:date',
#      'tactile_paving',
#      'takeaway',
#      'terrace',
#      'toilets',
#      'toilets:disposal',
#      'toilets:wheelchair',
#      'tourism',
#      'traffic_calming',
#      'train',
#      'tram',
#      'trolley_wire',
#      'type',
#      'url',
#      'usage',
#      'verified',
#      'water',
#      'waterway',
#      'website',
#      'wheelchair',
#      'wheelchair:description',
#      'wifi',
#      'wikidata',
#      'wikipedia',
#      'wpt_description'])

# %% [markdown]
# For the purposes of this project, I have decided to "clean" the following tags with the following conventions in mind:
# 1. Streets
#  - _Convention_: e.g., `Waller Street`
#  - This convention favors street names without specifying numbers (i.e., without suite number, house number, unit number) or abbreviations _unless_ the street has a widely known and accepted name that deviates from the aforementioned convention.
# 2. Phone Numbers
#  - _Convention_: e.g., `(415) 123-4567`
# 3. Zip Codes
#  - _Convention_: e.g., `94102`

# %% [markdown]
# ### Streets
#
# The first attribute I will clean will be `addr:street` according to the conventions specified above. The code below checks the _street type_ by comparing the last word in a street name to a list of expected street types (as per the Udacity case study preceding this project).

# %%
# Audits elements that have 'addr:street' tags
def street_audit():

    # Initialize variables and Regex and helper functions
    street_types = defaultdict(set)
    street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

    expected_streets = ["Avenue", "Street", "Boulevard", "Drive", "Lane", "Place",
                "Road", "Circle", "Parkway", "Court", "Way", "Terrace", "Alley",
                "Crescent", "Highway", "Junction", "Loop", "Trail", "Landing", "Walk",
                "Route", "Center", "Plaza"]

    def audit_street_type(street_types, street_name):
        m = street_type_re.search(street_name)
        if m:
            street_type = m.group()
            if street_type not in expected_streets:
                street_types[street_type].add(street_name)

    def is_street_name(elem):
        return (elem.attrib["k"] == "addr:street")
    
    # Loop through all top level tags
    for event, elem in ET.iterparse(osm_data, events=("start",)):
        for tag in elem.iter("tag"):

            # Audits street names
            if is_street_name(tag):
                audit_street_type(street_types, tag.attrib["v"])
                    
    return street_types

with open("SF_extract.osm", "r") as osm_data:
    unexpected_streets = street_audit()

unexpected_streets
# Out:
# defaultdict(set,
#             {'151': {'Brannan St #151'},
#              '15th': {'15th'},
#              '2': {'San Francisco Bicycle Route 2'},
#              '203': {'Bartlett Street #203'},
#              '3500': {'Sansome St #3500'},
#              '3658': {'Market Street Suite 3658'},
#              '39': {'Pier 39'},
#              '4.5': {'SF 80 PM 4.5'},
#              '404': {'16th St #404'},
#              '730': {'Sansome Street Ste 730', 'Sansome Street Suite 730'},
#              'A': {'Avenue A', 'Pier 50 A'},
#              'Ave': {'Geneva Ave',
#               'Grant Ave',
#               'Jerrold Ave',
#               'Morena Ave',
#               'Pennsylvania Ave',
#               'Phelan Ave',
#               'Van Ness Ave'},
#              'B': {'Avenue B', 'Pier 50 B'},
#              'Bldg': {'Ferry Bldg'},
#              'Blvd': {'Marina Blvd', 'Terry A Francois Blvd'},
#              'Broadway': {'Broadway'},
#              'Building': {'Ferry Building', 'Multi Use Building'},
#              'California': {'California'},
#              'D': {'Avenue D', 'Marina Boulevard Building D'},
#              'E': {'Avenue E'},
#              'East': {'Buena Vista Avenue East'},
#              'Embarcadero': {'Embarcadero', 'The Embarcadero'},
#              'F': {'Avenue F'},
#              'Ferlinghetti': {'Via Ferlinghetti'},
#              'Francisco': {'19th & Linda San Francisco'},
#              'G': {'Avenue G'},
#              'Gough': {'Gough'},
#              'H': {'Avenue H'},
#              'Hyde': {'Hyde'},
#              'King': {'King'},
#              'M': {'Avenue M'},
#              'Mall': {'Pacific Avenue Mall'},
#              'Mar': {'El Camino del Mar'},
#              'Mason': {'Fort Mason', 'Mason'},
#              'Montgomery': {'New Montgomery'},
#              'Ness': {'Van Ness'},
#              'North': {'Mission Bay Boulevard North', 'Willard North'},
#              'Palms': {'Avenue of the Palms'},
#              'Park': {'South Park'},
#              'Pier': {'Pier'},
#              'Pollard': {'Pollard'},
#              'Post': {'Post'},
#              'Powell': {'Bay and Powell'},
#              'Rock': {'Mission Rock'},
#              'St': {'14th St',
#               '19th St',
#               '24th St',
#               '9th St',
#               'Castro St',
#               'Cesar Chavez St St',
#               'Connecticut St',
#               'Green St',
#               'Hayes St',
#               'Kearny St',
#               'Leavenworth St',
#               'Market St',
#               'Mendell St',
#               'Missouri St',
#               'New Montgomery St',
#               'Noe St',
#               'Valencia St',
#               'Williams St',
#               'York St'},
#              'St.': {'California St.',
#               'Halleck St.',
#               'Market St.',
#               "O'Farrell St."},
#              'Stairway': {'Vallejo Street Stairway'},
#              'Vallejo': {'Vallejo'},
#              'Wedemeyer': {'Wedemeyer'},
#              'West': {'Buena Vista Avenue West'},
#              'Wharf': {'Fishermans Wharf'},
#              'st': {'2640 mason st', 'Kearny st'},
#              'street': {'Vallejo street'}})

# %% [markdown]
# **Observation #3**: Here we see that there are inconsistencies with street information, which is unsurprising given the variable nature people refer to streets.
#
# Here are some common issues, as noted in the audit above (and subsequent audit iterations):
#
# - Variable street type abbreviations (e.g, "Ave" vs. "AVE" vs. "Ave.")
# - Sequencing of street modifiers (e.g., "North Willard Street" vs. "Willard North")
# - Many streets were named correctly, but lacked a proper suffix (e.g., "Hyde" vs. "Hyde Street")
# - Some streets were listed as intersections and not detected by the above approach (e.g., "Murray Street And Justin Drive" would pass the naïve regex in the audit function above).

# %% [markdown]
# The second street audit below checks for streets that have numbers either prepended or appended for whatever reason (e.g., house numbers).

# %%
# Audits elements that have 'addr:street' tags
def street_audit2():

    # Initialize variables and Regex and helper functions
    streets_with_prefixes = []
    units_re = re.compile(r'^#?\d+\b.*|.*\b#?\d+$')

    def audit_street_prefix(street_name):
        m = units_re.search(street_name)
        if m:
            streets_with_prefixes.append(m.group())

    def is_street_name(elem):
        return (elem.attrib["k"] == "addr:street")
    
    # Loop through all top level tags
    for event, elem in ET.iterparse(osm_data, events=("start",)):
        for tag in elem.iter("tag"):

            # Audits street names
            if is_street_name(tag):
                audit_street_prefix(tag.attrib["v"])
                    
    return streets_with_prefixes

with open("SF_extract.osm", "r") as osm_data:
    unexpected_streets2 = street_audit2()

test_cases = set(unexpected_streets2)
test_cases
# Out:
# {'16th St #404',
#  '2640 mason st',
#  '30 Rickard Street',
#  '303 Second Street',
#  '434 Main Street',
#  'Bartlett Street #203',
#  'Brannan St #151',
#  'Market Street Suite 3658',
#  'Pier 39',
#  'SF 80 PM 4.5',
#  'San Francisco Bicycle Route 2',
#  'Sansome St #3500',
#  'Sansome Street Ste 730',
#  'Sansome Street Suite 730'}

# %% [markdown]
# (See `audit.py` for the functions defined specifically to fix these issues raised in the auditing procedure above!)

# %% [markdown]
# ### Phone Numbers

# %% [markdown]
# I chose the `phone` attribute (read: phone numbers) because that's another feature that has decent conventions by which we can standardize the available data.

# %%
# Initialize variables and Regex and helper functions
phone_re = re.compile(r'''(
    (\d{3}|\(\d{3}\))?                # area code
    (\s|-|\.)?                        # separator
    (\d{3})                           # first 3 digits
    (\s|-|\.)?                         # separator
    (\d{4})                           # last 4 digits
    (\s*(ext|x|ext.)\s*(\d{2,5}))?    # extension
    )''', re.VERBOSE)

# Audits elements that have 'phone' tags
def phone_audit():

    thrown_out = set()
    weirdest_nums = set()
    semi_normal_nums = set()
    
    def audit_phone_num(phone_num):

        # Checks to see if number characters present is conceivably a phone number
        stripped_num = re.sub(r'[^0-9a-zA-Z]', '', phone_num)
        if len(stripped_num) < 7 or len(stripped_num) > 15:
            thrown_out.add(phone_num)
            return
        
        m = phone_re.search(phone_num)
        if not m:
            weirdest_nums.add(phone_num)
        else:
            semi_normal_nums.add(phone_num)

    def is_phone_number(elem):
        return (elem.attrib["k"] == "phone")
    
    # Loop through all top level tags
    for event, elem in ET.iterparse(osm_data, events=("start",)):
        for tag in elem.iter("tag"):

            # Audits phone numbers
            if is_phone_number(tag):
                audit_phone_num(tag.attrib["v"])
            
    return weirdest_nums, semi_normal_nums, thrown_out

with open("SF_extract.osm", "r") as osm_data:
    weird_nums, semi_norm_nums, thrown_out = phone_audit()

pp.pprint(weird_nums)
# Out:
# set(['(+1) 415 291 20 33',
#      u'(415) 549\u20137932',
#      '(415) 735 - 6843',
#      '+1 415 759 TOYS',
#      '415 242 960',
#      '415 409 FARM',
#      '415-397-BROS'])

# %% [markdown]
# **Observation #4**: The mnemonic endings (e.g., 'FARM', 'BROS') to a few of these phone required a little bit of decoding, otherwise most of the phone numbers follow common phone number formats (given the dearth of items in `weird_nums`).
#
# >**Note**: The regular expression (regex) employed in the phone number audit function above captured most of the variability in phone number formats.
#
# (See `audit.py` for defined functions that deal with these inconsistencies among formats!)

# %% [markdown]
# ### ZIP Codes

# %% [markdown]
# The code below separates the _obviously_ suspect (read: `weird`) zip (read: postal) codes from those that _appear_ normal. The

# %%
# Initialize variables and Regex and helper functions
zip_re = re.compile(r'^(94\d{3})(-\d{4})?$')

# Audits elements that have 'postcode' tags
def zip_audit():
   
    weird_zips = set()
    normal_zips = set()
    
    def audit_zip(zip_code):
        m = zip_re.search(zip_code)
        if not m:
            weird_zips.add(zip_code)
        else:
            normal_zips.add(m.group(1))

    def is_zip(elem):
        return (elem.attrib["k"] == "addr:postcode")
    
    # Loop through all top level tags
    for event, elem in ET.iterparse(osm_data, events=("start",)):
        for tag in elem.iter("tag"):

            # Audits zip numbers
            if is_zip(tag):
                audit_zip(tag.attrib["v"])
            
    return weird_zips, normal_zips

with open("SF_extract.osm", "r") as osm_data:
    weird, normal = zip_audit()

pp.pprint(weird)
# Out:
# set(['14123', '41907', '90214', '95115', 'CA'])

# %% [markdown]
# **Observation #5**: Zip codes were generally already pretty clean (or followed standard conventions, even if these conventions were not aligned with the one with which I'm subscribing to).
#
# These `weird` zip codes are corrected in `audit.py`, which demonstrates that many errors likely resulted from user input, such as:
# - Switched digits (e.g., `94013` vs. `94103`)
# - Incorrectly substituted digits (e.g., `14123` vs. `94123`)
# - Incorrect digits repeated (e.g., `94113` vs. `94133`)
#
# One way the above error patterns were made evident to me was by employing the code below, which returns a table consisting of zip codes that appear normal (i.e., their first two digits are `94`) but do not map to cities in the map extract area (i.e., San Francisco, Daly City, and Sausalito).

# %%
# Custom helper function to check each zipcode against database
def zip_city_checker(z):
    zcdb = ZipCodeDatabase()
    try:
        return zcdb[z].city
    except:
        return np.nan

# Checks the seemingly 'normal' zipcodes for issues
cities = []
for zipcode in normal:
    cities.append(zip_city_checker(zipcode))

df_zip_cities = pd.DataFrame({'ZIP': list(normal), 'City': cities})
ok_cities = ['San Francisco', 'Daly City', 'Sausalito']
cond = df_zip_cities['City'].apply(lambda x: x not in ok_cities)
df_zip_cities[cond]
# Out:
#          City    ZIP
# 8         NaN  94113
# 13        NaN  94158
# 17  Sunnyvale  94087
# 35        NaN  94013

# %% [markdown]
# In my cleaning code (`audit.py`) I revisited the `94...` zip codes in the above table, which required me to find the associated `nodes` in the OSM file and to replace these erroneous zip codes with the actual zip code contained in the researched address for given `node`s.

# %% [markdown]
# ## Confirming Cleaned Data

# %% [markdown]
# Here, I'm checking **streets** by looking at the most infrequently appearing streets as those are the most likely to be aberrant.

# %%
# Query
final_query = '''
SELECT tags.value, COUNT(*) AS num, tags.type
FROM (SELECT * FROM nodes_tags UNION ALL SELECT * FROM ways_tags) AS tags
WHERE (tags.key == "street") AND (tags.type == "addr")
GROUP BY tags.value
HAVING (num < 5)
ORDER BY num, tags.value;
'''


# Query to Pandas DataFrame
df_streets = pd.read_sql_query(final_query, conn)
df_streets
# Out:
#                              value  num  type
# 0                      12th Street    1  addr
# 1                    Amador Street    1  addr
# 2                      Amber Drive    1  addr
# 3                     Aptos Avenue    1  addr
# 4                 Arlington Street    1  addr
# 5                     Armory Drive    1  addr
# 6                         Avenue B    1  addr
# 7                         Avenue E    1  addr
# 8                         Avenue F    1  addr
# 9                         Avenue G    1  addr
# 10                        Avenue M    1  addr
# 11                    Bacon Street    1  addr
# 12                   Bartol Street    1  addr
# 13                  Belcher Street    1  addr
# 14                   Beulah Street    1  addr
# 15                 Bosworth Street    1  addr
# 16                   Brazil Avenue    1  addr
# 17                  Brosnan Street    1  addr
# 18         Buena Vista Avenue East    1  addr
# 19                     Butte Place    1  addr
# 20                   Campton Place    1  addr
# 21                  Carroll Avenue    1  addr
# 22                    Clara Street    1  addr
# 23                  Clarence Place    1  addr
# 24         Colin P Kelly Jr Street    1  addr
# 25               Commercial Street    1  addr
# 26                    Compton Road    1  addr
# 27                  Conzelman Road    1  addr
# 28                     Cosmo Place    1  addr
# 29            Daniel Burnham Court    1  addr
# 30                  Danvers Street    1  addr
# 31                      Darien Way    1  addr
# 32                  De Boom Street    1  addr
# 33              De Montfort Avenue    1  addr
# 34                       Dow Place    1  addr
# 35                   Dublin Street    1  addr
# 36               El Camino Del Mar    1  addr
# 37                     Elim Street    1  addr
# 38                Ellsworth Street    1  addr
# 39                   Elmira Street    1  addr
# 40                     Embarcadero    1  addr
# 41                     Erie Street    1  addr
# 42                Escondido Avenue    1  addr
# 43                   Eureka Street    1  addr
# 44                 Everglade Drive    1  addr
# 45                  Federal Street    1  addr
# 46                     Ferry Plaza    1  addr
# 47                    Flood Avenue    1  addr
# 48               Fort Mason Center    1  addr
# 49                  Francis Street    1  addr
# 50                  Freelon Street    1  addr
# 51                    Funston Road    1  addr
# 52                    Gaven Street    1  addr
# 53                  Gilbert Street    1  addr
# 54                   Gilman Avenue    1  addr
# 55       Hagiwara Tea Garden Drive    1  addr
# 56                  Halleck Street    1  addr
# 57                Hampshire Street    1  addr
# 58                    Hardie Place    1  addr
# 59                    Harding Road    1  addr
# 60              Henry Adams Street    1  addr
# 61                     Herbst Road    1  addr
# 62                     Hoff Street    1  addr
# 63               Holly Park Circle    1  addr
# 64                   Hooper Street    1  addr
# 65                   Hudson Street    1  addr
# 66               Industrial Street    1  addr
# 67             Isadora Duncan Lane    1  addr
# 68                    Italy Avenue    1  addr
# 69            John F Kennedy Drive    1  addr
# 70                    Joost Avenue    1  addr
# 71               Jose Sarria Court    1  addr
# 72            Juan Bautista Circle    1  addr
# 73                    Justin Drive    1  addr
# 74                       Koret Way    1  addr
# 75                  Lansing Street    1  addr
# 76              Leidesdorff Street    1  addr
# 77                Lexington Street    1  addr
# 78                     Lilac Alley    1  addr
# 79               Lincoln Boulevard    1  addr
# 80                    Linda Street    1  addr
# 81                   Linden Street    1  addr
# 82                   London Street    1  addr
# 83                     Lusk Street    1  addr
# 84                    Lyell Street    1  addr
# 85                     Maiden Lane    1  addr
# 86     Marina Boulevard Building D    1  addr
# 87                  Mendell Street    1  addr
# 88                   Mersey Street    1  addr
# 89                   Milton Street    1  addr
# 90                Minnesota Street    1  addr
# 91                     Mint Street    1  addr
# 92              Mississippi Street    1  addr
# 93                   Morena Avenue    1  addr
# 94               Morningside Drive    1  addr
# 95                      Museum Way    1  addr
# 96           Music Concourse Drive    1  addr
# 97                 Napoleon Street    1  addr
# 98                   Nellie Street    1  addr
# 99                   Nevada Street    1  addr
# 100                 Niagara Avenue    1  addr
# 101                     Oriole Way    1  addr
# 102                 Panorama Drive    1  addr
# 103                    Paul Avenue    1  addr
# 104                 Pershing Drive    1  addr
# 105                  Phelps Street    1  addr
# 106                      Pier 40 A    1  addr
# 107                      Pier 50 A    1  addr
# 108                      Pier 50 B    1  addr
# 109                  Pioche Street    1  addr
# 110                   Plaza Street    1  addr
# 111                 Pollard Street    1  addr
# 112                 Rickard Street    1  addr
# 113                Rosenstock Road    1  addr
# 114                  Russia Avenue    1  addr
# 115                   SF 80 PM 4.5    1  addr
# 116            Saint Francis Place    1  addr
# 117  San Francisco Bicycle Route 2    1  addr
# 118                San Juan Avenue    1  addr
# 119               Saramento Street    1  addr
# 120                  Second Street    1  addr
# 121     Sergeant John V Young Lane    1  addr
# 122                 Shafter Avenue    1  addr
# 123                  Sharon Street    1  addr
# 124                Sheridan Avenue    1  addr
# 125                Shotwell Street    1  addr
# 126                  Silver Avenue    1  addr
# 127                Somerset Street    1  addr
# 128                South Gate Road    1  addr
# 129                 Staples Avenue    1  addr
# 130                   Stark Street    1  addr
# 131                     Summit Way    1  addr
# 132                  Tehama Street    1  addr
# 133          Terry Francois Street    1  addr
# 134                   Third Street    1  addr
# 135                  Tillman Place    1  addr
# 136           United Nations Plaza    1  addr
# 137        Vallejo Street Stairway    1  addr
# 138                Van Dyke Avenue    1  addr
# 139               Via Ferlinghetti    1  addr
# 140                   Vine Terrace    1  addr
# 141                Virginia Avenue    1  addr
# 142             Walter U Lum Place    1  addr
# 143                 Wayland Street    1  addr
# 144               Wedemeyer Street    1  addr
# 145                Wentworth Place    1  addr
# 146           Whitney Young Circle    1  addr
# 147                  Wilder Street    1  addr
# 148          William Saroyan Place    1  addr
# 149                Williams Avenue    1  addr
# 150                Williams Street    1  addr
# 151              Willie Mays Plaza    1  addr
# 152                     Yacht Road    1  addr
# 153                Yosemite Avenue    1  addr
# 154                     Zoo Avenue    1  addr
# 155                    13th Street    2  addr
# 156                 Alameda Street    2  addr
# 157                    Ames Street    2  addr
# 158                   August Alley    2  addr
# 159                    Behr Avenue    2  addr
# 160                  Belles Street    2  addr
# 161                 Buckingham Way    2  addr
# 162               Cambridge Street    2  addr
# 163                   Cascade Walk    2  addr
# 164            Cervantes Boulevard    2  addr
# 165                 Channel Street    2  addr
# 166             Charter Oak Avenue    2  addr
# 167                    Claude Lane    2  addr
# 168         Columbia Square Street    2  addr
# 169            Cyril Magnin Street    2  addr
# 170                 Decatur Street    2  addr
# 171                Delancey Street    2  addr
# 172                  Delmar Street    2  addr
# 173                  Deming Street    2  addr
# 174                  Edward Street    2  addr
# 175                    Escolta Way    2  addr
# 176                Farnsworth Lane    2  addr
# 177               Fishermans Wharf    2  addr
# 178                Florence Street    2  addr
# 179                 Font Boulevard    2  addr
# 180              Forest View Drive    2  addr
# 181                  Fowler Avenue    2  addr
# 182                     Garden Way    2  addr
# 183                  Geneva Avenue    2  addr
# 184                Grenard Terrace    2  addr
# 185                 Harriet Street    2  addr
# 186               Hawthorne Street    2  addr
# 187                    Hays Street    2  addr
# 188                 Heather Avenue    2  addr
# 189                Illinois Street    2  addr
# 190                 Indiana Street    2  addr
# 191                Inverness Drive    2  addr
# 192                     Ivy Street    2  addr
# 193                Jennings Street    2  addr
# 194                    Juri Street    2  addr
# 195                Kissling Street    2  addr
# 196                    Lake Street    2  addr
# 197                Letterman Drive    2  addr
# 198                   Marin Street    2  addr
# 199              Meadowbrook Drive    2  addr
# 200                  Merced Avenue    2  addr
# 201                Merchant Street    2  addr
# 202            Mission Rock Street    2  addr
# 203                 Norwich Street    2  addr
# 204               Nottingham Place    2  addr
# 205              Octavia Boulevard    2  addr
# 206                       Omar Way    2  addr
# 207                    Otis Street    2  addr
# 208            Pennsylvania Avenue    2  addr
# 209                  Pollard Place    2  addr
# 210                Presidio Avenue    2  addr
# 211               Presidio Terrace    2  addr
# 212                 Redfield Alley    2  addr
# 213              Richardson Avenue    2  addr
# 214                 Riverton Drive    2  addr
# 215                   Romolo Place    2  addr
# 216                  Roosevelt Way    2  addr
# 217             Russian Hill Place    2  addr
# 218              Springfield Drive    2  addr
# 219                   Sylvan Drive    2  addr
# 220               Tennessee Street    2  addr
# 221     Terry A Francois Boulevard    2  addr
# 222                 Tiffany Avenue    2  addr
# 223                Tompkins Avenue    2  addr
# 224                  Trinity Place    2  addr
# 225                 Vermont Street    2  addr
# 226               Wisconsin Street    2  addr
# 227                    York Street    2  addr
# 228                     Aerial Way    3  addr
# 229               Alcatraz Landing    3  addr
# 230              Alemany Boulevard    3  addr
# 231            Avenue Of The Palms    3  addr
# 232                   Belden Place    3  addr
# 233                  Boynton Court    3  addr
# 234                    Brush Place    3  addr
# 235                      Cargo Way    3  addr
# 236                Carolina Street    3  addr
# 237            Commonwealth Avenue    3  addr
# 238                  Constanso Way    3  addr
# 239               El Mirasol Place    3  addr
# 240                    Fanning Way    3  addr
# 241                 Ferry Building    3  addr
# 242                Germania Street    3  addr
# 243                    Hill Street    3  addr
# 244                 Hillcrest Road    3  addr
# 245                  Laurel Street    3  addr
# 246                  Loomis Street    3  addr
# 247                Mcreynolds Road    3  addr
# 248                    Mesa Avenue    3  addr
# 249              Middlefield Drive    3  addr
# 250                     Mint Plaza    3  addr
# 251                 Oakdale Avenue    3  addr
# 252                   Osgood Place    3  addr
# 253                    Palm Avenue    3  addr
# 254                  Phelan Avenue    3  addr
# 255                  Salmon Street    3  addr
# 256                 Uranus Terrace    3  addr
# 257                  Walter Street    3  addr
# 258                 Alabama Street    4  addr
# 259                       Avenue D    4  addr
# 260                   Baker Street    4  addr
# 261                Bartlett Street    4  addr
# 262          Bayside Village Place    4  addr
# 263                 Beckett Street    4  addr
# 264                 Bluxome Street    4  addr
# 265                Buchanan Street    4  addr
# 266                    Capp Street    4  addr
# 267                 Cecilia Avenue    4  addr
# 268                  Cortes Avenue    4  addr
# 269                Division Street    4  addr
# 270                   Gates Street    4  addr
# 271                Gateview Avenue    4  addr
# 272                  Hallam Street    4  addr
# 273                 Jerrold Avenue    4  addr
# 274                Johnstone Drive    4  addr
# 275                  Jordan Avenue    4  addr
# 276                 Liberty Street    4  addr
# 277                    Lily Street    4  addr
# 278                  Lomita Avenue    4  addr
# 279    Mission Bay Boulevard North    4  addr
# 280                Missouri Street    4  addr
# 281                  Murray Circle    4  addr
# 282                  Persia Avenue    4  addr
# 283                        Pier 39    4  addr
# 284                 Potrero Avenue    4  addr
# 285                 Precita Avenue    4  addr
# 286                  Radio Terrace    4  addr
# 287                 Rayburn Street    4  addr
# 288                 Ringold Street    4  addr
# 289                   Ritch Street    4  addr
# 290                 Rosemary Court    4  addr
# 291                     Ross Alley    4  addr
# 292        Saint Francis Boulevard    4  addr
# 293               San Bruno Avenue    4  addr
# 294                San Leandro Way    4  addr
# 295                  States Street    4  addr
# 296                   Treat Avenue    4  addr
# 297                  Winston Drive    4  addr
# 298               Yerba Buena Lane    4  addr

# %% [markdown]
# Looks good. Continuing onto checking **zip codes**:

# %%
# Query
final_query = '''
SELECT tags.value, COUNT(*) AS num, tags.type
FROM (SELECT * FROM nodes_tags UNION ALL SELECT * FROM ways_tags) AS tags
WHERE (tags.key == "postcode")
GROUP BY tags.value
ORDER BY num, tags.value;
'''


# Query to Pandas DataFrame
df_zips = pd.read_sql_query(final_query, conn)
df_zips
# Out:
#     value   num  type
# 0   94015     1  addr
# 1   94017     1  addr
# 2   94164     1  addr
# 3   94188     1  addr
# 4   94130     3  addr
# 5   94166     4  addr
# 6   94143     6  addr
# 7   94134     8  addr
# 8   94965     9  addr
# 9   94129    10  addr
# 10  94158    29  addr
# 11  94112    45  addr
# 12  94124    53  addr
# 13  94132    59  addr
# 14  94115    61  addr
# 15  94104    66  addr
# 16  94111    72  addr
# 17  94131   130  addr
# 18  94105   136  addr
# 19  94108   137  addr
# 20  94123   143  addr
# 21  94107   146  addr
# 22  94102   212  addr
# 23  94110   249  addr
# 24  94114   352  addr
# 25  94121   376  addr
# 26  94109   476  addr
# 27  94127   749  addr
# 28  94103   813  addr
# 29  94118  1119  addr
# 30  94133  1182  addr
# 31  94117  1456  addr
# 32  94116  2397  addr
# 33  94122  5116  addr

# %% [markdown]
# Here are the zipcodes that are _apparently not_ in the map extract area, even after cleaning has been completed.

# %%
df_zips['cities'] = df_zips['value'].apply(zip_city_checker)
cities = ['San Francisco', 'Daly City', 'Sausalito']
m = df_zips['cities'].apply(lambda x: x not in cities)
df_zips[m]
# Out:
#     value  num  type cities
# 10  94158   29  addr    NaN

# %% [markdown]
# `94158` is, indeed, a San Francisco zip code (the 29 instances are no coindence), but was not a zip code when the external Python library was written (early-mid 2000s)!
#
# Finally, I checked to see if there were any remaining problematic **phone** data:

# %%
# Query
final_query = '''
SELECT tags.id, tags.value, tags.type
FROM (SELECT * FROM nodes_tags UNION ALL SELECT * FROM ways_tags) AS tags
WHERE (tags.key == "phone") AND (tags.value IS NULL)
ORDER BY tags.value DESC;
'''


# Query to Pandas DataFrame
df_phones = pd.read_sql_query(final_query, conn)
df_phones
# Out:
# Empty DataFrame
# Columns: [tags.id, tags.value, tags.type]
# Index: []

# %% [markdown]
# (This empty table means everything has been cleaned!)

# %% [markdown]
# ## Exploring the Data
# First, let's take a look at some of the standard queries as per the project rubric, chiefly:
# - number of unique users/contributors
# - number of nodes and ways

# %% [markdown]
# ### Contributors
# This query takes a look at the top 10 contributors to the OSM SF extract.

# %%
# Query
final_query = '''
SELECT x.user, COUNT(*) AS "Number of Tags"
FROM (SELECT user FROM nodes UNION ALL SELECT user FROM ways) x
GROUP BY x.user
ORDER BY "Number of Tags" DESC
LIMIT 10;
'''


# Query to Pandas DataFrame
df_top_users = pd.read_sql_query(final_query, conn)
df_top_users
# Out:
#                  user  Number of Tags
# 0              ediyes          645049
# 1           Luis36995          452474
# 2               Rub21          328103
# 3         KindredCoda           55016
# 4          AndrewSnow           40220
# 5    upendra_sfimport           27238
# 6   saikabhi_sfimport           26579
# 7            osmmaker           21056
# 8  BharataHS_sfimport           20785
# 9         brentengust           19895

# %% [markdown]
# ### Nodes and Ways
#
# Counting nodes and ways requires understanding that OSM `id`s are **_not_** unique across object type (i.e., `node`, `way`, etc.), but _are_ unique within an object type. This distinction is illustrated below (and corroborated [here](https://gis.stackexchange.com/questions/103572/are-osm-ids-unique-over-all-object-types)).

# %%
# Query
final_query = '''
SELECT COUNT(id), COUNT(DISTINCT id)
FROM (SELECT id,user,uid,version,changeset,timestamp FROM nodes UNION ALL SELECT * FROM ways) x
LIMIT 10;
'''


# Query to Pandas DataFrame
df_ways_nodes = pd.read_sql_query(final_query, conn)
df_ways_nodes
# Out:
#    COUNT(id)  COUNT(DISTINCT id)
# 0    1859127             1859095

# %% [markdown]
# Therefore, the best **count of `way`s and `node`s** in the database is **1,859,127**.

# %% [markdown]
# ### Cafes
#
# The first exercise is **finding all of the coffee shops with internet access and all coffee shops around my home**. The second is to **find all of the coffee shops around my home that have internet access**.
#
# Here are the cafes with internet access in San Fransisco:

# %%
# Query for cafes with internet access
query_cafe_names = 'SELECT nodes_tags.id, nodes.lat, nodes.lon, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "name"'
query_cafe_amenities = 'SELECT nodes_tags.id, nodes_tags.key, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "amenity"'
query_cafe_internetaccess = 'SELECT nodes_tags.id, nodes_tags.key, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "internet_access"'

query_cafes = 'SELECT DISTINCT q1.id AS "id", q1.lat AS "Latitude", q1.lon AS "Longitude", q1.value AS "Cafe Name", q3.value AS "Internet Access" FROM (({}) q1 JOIN ({}) q2 ON q1.id == q2.id) JOIN ({}) q3 ON q3.id == q1.id WHERE q2.value == "cafe";'.format(query_cafe_names, query_cafe_amenities, query_cafe_internetaccess)


# Query to Pandas DataFrame
df_internetcafe = pd.read_sql_query(query_cafes, conn)
df_internetcafe
# Out:
#             id   Latitude   Longitude                     Cafe Name  \
# 0    331389010  37.798631 -122.407352                 Caffe Trieste
# 1    332787308  37.787094 -122.456387                 Picnix Bistro
# 2    360450263  37.751121 -122.438327                  Philz Coffee
# 3    376235927  37.806556 -122.420377                     Starbucks
# 4    410845445  37.790168 -122.415411                  Another Cafe
# 5    443372068  37.756417 -122.421229        Ritual Coffee Roasters
# 6    586713622  37.764849 -122.432012           Peet's Coffee & Tea
# 7    679010814  37.775598 -122.393369                  Philz Coffee
# 8    725100826  37.787163 -122.410788                     Starbucks
# 9    747853234  37.796800 -122.421770                         Crave
# 10   968355348  37.741697 -122.422572                Cafe St. Jorge
# 11  1306052376  37.754156 -122.481308       Henry's House of Coffee
# 12  1393986237  37.783201 -122.406837                    Cafe Venue
# 13  1762825978  37.780834 -122.464459                     Cafe Coco
# 14  1769223520  37.780286 -122.476381           Royal Ground Coffee
# 15  1809593836  37.733565 -122.489701                 Peet's Coffee
# 16  1846461309  37.796757 -122.422118                     Starbucks
# 17  1956078877  37.775725 -122.446378                     Starbucks
#
#    Internet Access
# 0              yes
# 1               no
# 2             wlan
# 3             wlan
# 4              yes
# 5              yes
# 6              yes
# 7             wlan
# 8             wlan
# 9              yes
# 10            wlan
# 11             yes
# 12   wlan;terminal
# 13             yes
# 14             yes
# 15             yes
# 16            wlan
# 17            wlan
# 18            wlan
# 19            wlan
# 20            wlan
# 21            wlan
# 22            wlan
# 23             yes
# 24             yes
# 25             yes
# 26              no
# 27             yes
# 28             yes
# 29              no
# 30             yes
# 31              no
# 32             yes
# 33             yes
# 34              no
# 35             yes
# 36              no
# 37             yes
# 38              no
# 39            wlan
# 40            wlan
# 41              no
# 42             yes
# 43            wlan
# 44            wlan
# 45            wlan
# 46            wlan
# 47            wlan
# 48             yes
# 49            wlan
# 50            wlan
# 51              no
# 52             yes
# 53             yes
# 54            wlan
# 55            wlan
# 56             yes
# 57            wlan
# 58            wlan
# 59            wlan
# 60            wlan
# 61              no
# 62            wlan
# 63            wlan
# 64            wlan
# 65            wlan
# 66            wlan
# 67             yes
# 68            wlan

# %% [markdown]
# Here are the coffee shops around my home:

# %%
# Do geographic calculations
'''
Each 1 degree of LAT is approximately 69.172 miles
Each 1 degree LONG is a function of LAT
'''

lat_home = 37.771715
long_home = -122.424494
delta_LAT_1degree_miles_EQUATOR = 69.172

delta_LAT_1mile_degrees = 1 / delta_LAT_1degree_miles_EQUATOR
delta_LONG_1degree_miles = math.cos(math.radians(lat_home)) * delta_LAT_1degree_miles_EQUATOR
delta_LONG_1mile_degrees = 1 / delta_LONG_1degree_miles

sq_miles = 1.0
delta_long = delta_LONG_1mile_degrees * sq_miles**0.5 / 2
delta_lat = delta_LAT_1mile_degrees * sq_miles**0.5 / 2

range_long = (long_home - delta_long, long_home + delta_long)
range_lat = (lat_home - delta_lat, lat_home + delta_lat)

# Query for cafes near me
query_cafe_names_nearme = 'SELECT nodes_tags.id, nodes.lat, nodes.lon, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "name"'
query_cafe_amenities_nearme = 'SELECT nodes_tags.id, nodes_tags.key, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "amenity" AND value == "cafe" AND lat >= {} AND lat <= {} AND lon >= {} AND lon <= {} ORDER BY value'.format(range_lat[0], range_lat[1], range_long[0], range_long[1])
query_cafes_nearme = 'SELECT DISTINCT q1.id AS "id", q1.lat AS "Latitude", q1.lon AS "Longitude", q1.value AS "Cafe Name" FROM ({}) q1 JOIN ({}) q2 ON q1.id == q2.id WHERE q2.value == "cafe"'.format(query_cafe_names_nearme, query_cafe_amenities_nearme)
query_cafes_streets = 'SELECT nodes_tags.id, nodes.lat, nodes.lon, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "street"'

final_query = 'SELECT cafes.*, streets.value AS "Street" FROM ({}) cafes LEFT JOIN ({}) streets ON cafes.id = streets.id'.format(query_cafes_nearme, query_cafes_streets)

# Query to Pandas DataFrame
df_nearme = pd.read_sql_query(final_query, conn)
df_nearme
# Out:
#             id   Latitude   Longitude                 Cafe Name  \
# 0    411083201  37.767316 -122.421948        Four Barrel Coffee
# 1    418513660  37.764500 -122.421681              Muddy Waters
# 2    528057543  37.768212 -122.422386             Carlin's Cafe
# 3    586713622  37.764849 -122.432012       Peet's Coffee & Tea
# 4    647656728  37.771672 -122.433137                    Nectar
# 5    647656785  37.772169 -122.430725        Cafe International
# 6   1493456455  37.776359 -122.418088                 Ma'velous
# 7   1493456487  37.777046 -122.417274                 Starbucks
# 8   2005894602  37.769072 -122.427724                 Starbucks
# 9   2095344770  37.766319 -122.417422         Flying Pig Bistro
# 10  2187987262  37.766425 -122.429039        Church Street Cafe
# 11  2411692096  37.777038 -122.417570           Anderson Bakery
# 12  2411698457  37.776311 -122.423256        Blue Bottle Coffee
# 13  2474058013  37.773986 -122.424226              mercury cafe
# 14  2474058022  37.774748 -122.422688          gourmet and more
# 15  2881830804  37.775488 -122.415900                   Cumaica
# 16  2895323815  37.775217 -122.419519             All Star Cafe
# 17  2895323816  37.775914 -122.419191               Boston Cafe
# 18  2983919102  37.774459 -122.420588           Javalencia Cafe
# 19  3321734312  37.776017 -122.431495         Alamo Square Cafe
# 20  3641568148  37.776240 -122.416876        Blue Bottle Coffee
# 21  4010355532  37.765011 -122.422669                    Stanza
# 22  4030622426  37.769195 -122.431540          Duboce Park Cafe
# 23  4037746568  37.775045 -122.421056                 Eden Cafe
# 24  4055719117  37.772671 -122.422074  Delessio Market & Bakery
# 25  4259001279  37.771778 -122.416714              Gaslamp Cafe
# 26  4340535594  37.774525 -122.430648   The Center SF Tea House
# 27  4625994189  37.776894 -122.424540               Cafe la Vie
# 28  4666687025  37.775282 -122.416138             Peet's Coffee
#
#                    Street
# 0         Valencia Street
# 1         Valencia Street
# 2         Valencia Street
# 3           Market Street
# 4           Haight Street
# 5           Haight Street
# 6           Market Street
# 7           Market Street
# 8           Market Street
# 9   South Van Ness Avenue
# 10                   None
# 11                   None
# 12                   None
# 13         Octavia Street
# 14                   None
# 15         Mission Street
# 16          Market Street
# 17        Van Ness Avenue
# 18          Market Street
# 19                   None
# 20          Market Street
# 21                   None
# 22         Sanchez Street
# 23        Franklin Street
# 24          Market Street
# 25          Howard Street
# 26        Fillmore Street
# 27         Octavia Street
# 28                   None

# %% [markdown]
# Let's visually double-check these selected longitude & latitude value pairs on a map.

# %%
# Imports dependency used to drop markers onto a map
import folium

# Isolating "northing" and "easting" information with labels for each point
locationlist = df_nearme[["Latitude","Longitude"]].values.tolist()
labels = df_nearme["Cafe Name"].values.tolist()

# Create map and drop points onto it
m = folium.Map(location=[lat_home, long_home], zoom_start=14)
for point in range(len(locationlist)):
    folium.Marker(locationlist[point]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Here are the coffee shops around my home with internet access (I'm using `pandas` because I'm already working with two DataFrames.

# %%
df = df_internetcafe.merge(df_nearme, how="inner", on=[u'id', u'Latitude', u'Longitude', u'Cafe Name'])
df[df["Internet Access"] != "no"]
# Out:
#            id   Latitude   Longitude            Cafe Name Internet Access  \
# 0   586713622  37.764849 -122.432012  Peet's Coffee & Tea             yes
# 1  2005894602  37.769072 -122.427724            Starbucks            wlan
# 2  2095344770  37.766319 -122.417422    Flying Pig Bistro            wlan
# 3  2187987262  37.766425 -122.429039   Church Street Cafe             yes
#
#                   Street
# 0          Market Street
# 1          Market Street
# 2  South Van Ness Avenue
# 3                   None

# %% [markdown]
# **Observation #6**: Some of these data are outdated (e.g., Mission Creek Cafe and Little Bird Cafe are no longer in business). Additionally, I know there are a ton more around me (especially in Hayes Valley and the Mission neighborhoods) that aren't reflected in the data!

# %% [markdown]
# The next step is to take this observation to the next level: **find the coffee shops with internet along a bike route!**
#
# I start with identifying `cycleways` ways tags, figuring out what nodes on on `cycleways`, and finally, joining those nodes with the nodes identified as cafes.

# %%
# Queries to find coffee shops on bike paths
cycleway_ids = '''
SELECT ways.id AS ways_id
FROM ways_tags LEFT JOIN ways ON ways_tags.id == ways.id 
WHERE key == "cycleway" 
OR (key == "bicycle" AND value == "yes")
OR (key == "highway" AND value == "cycleway")
'''

nodes_on_cycleways = 'SELECT cycleway_ids.ways_id AS cycleway_id, ways_nodes.node_id AS nodes_on_cycleway_id FROM ({}) cycleway_ids LEFT JOIN ways_nodes ON ways_nodes.id == cycleway_ids.ways_id ORDER BY cycleway_id, nodes_on_cycleway_id'.format(cycleway_ids.strip('\n'))
queryA = 'SELECT nodes_on_cycleway.*, nodes.lat, nodes.lon FROM ({}) nodes_on_cycleway LEFT JOIN nodes ON nodes.id == nodes_on_cycleway.nodes_on_cycleway_id'.format(nodes_on_cycleways)
queryB = 'SELECT qA.*, nodes_tags.key, nodes_tags.value FROM ({}) qA LEFT JOIN nodes_tags ON qA.nodes_on_cycleway_id == nodes_tags.id WHERE (nodes_tags.key == "amenity") AND (nodes_tags.value == "cafe")'.format(queryA)

# Query to Pandas DataFrame
df = pd.read_sql_query(queryB, conn)
df
# Out:
# Empty DataFrame
# Columns: [cycleway_id, nodes_on_cycleway_id, lat, lon, nodes_tags.key, nodes_tags.value]
# Index: []

# %% [markdown]
# **Observation #7:** This doesn't seem to work because the `ways_nodes` are those designations that _define the path_ itself (rather than things _along_ the path).

# %%
# Query to see what types of `nodes` comprise bike paths
queryC = 'SELECT qA.*, nodes_tags.key, nodes_tags.value FROM ({}) qA LEFT JOIN nodes_tags ON qA.nodes_on_cycleway_id == nodes_tags.id WHERE (nodes_tags.key != "None") ORDER BY nodes_tags.key, nodes_tags.value'.format(queryA)

# Query to Pandas DataFrame
df = pd.read_sql_query(queryC, conn)
df
# Out:
#       cycleway_id  nodes_on_cycleway_id        lat         lon  \
# 0        26378110            2399952061  37.743991 -122.421991
# 1       359385451             667197531  37.832255 -122.480953
# 2       359385451             667197531  37.832255 -122.480953
# 3       368033990             667115758  37.832340 -122.480608
# 4       368049578             667197531  37.832255 -122.480953
# 5       368049578             667197531  37.832255 -122.480953
# 6       419755787             667115758  37.832340 -122.480608
# 7        24354980            1142601042  37.809409 -122.412610
# 8        31934807            1142601108  37.795122 -122.391557
# 9        46274020             590986805  37.778163 -122.387559
# 10       98752555            1142601033  37.809581 -122.412290
# 11       98759331            1142640642  37.796881 -122.393131
# 12       98759351            1142640642  37.796881 -122.393131
# 13       98763155             590986805  37.778163 -122.387559
# 722     106042063            2638978411  37.810046 -122.476427
# 723     108194449              65306190  37.730925 -122.410610
# 724     108194449            1241673308  37.728679 -122.425252
# 725     108194449            1241673342  37.728767 -122.423638
# ...
# 3535    traffic_calming                                               hump
# 3536    traffic_calming                                               hump
# 3537    traffic_calming                                               hump
# 3538    traffic_calming                                               hump
# 3539    traffic_calming                                               hump
# 3540    traffic_calming                                               hump
# 3541    traffic_calming                                             island
# 3542    traffic_calming                                             island
# 3543    traffic_calming                                             island
# 3544    traffic_calming                                             island
# 3545    traffic_signals                                             signal
# 3546    traffic_signals                                             signal
# 3547    traffic_signals                                             signal
# 3548    traffic_signals                                             signal
# 3549    traffic_signals                                             signal
# 3550    traffic_signals                                             signal
# 3551    traffic_signals                                             signal
# 3552    traffic_signals                                             signal
# 3553    traffic_signals                                             signal
# 3554    traffic_signals                                             signal
# 3555    traffic_signals                                             signal
# 3556    traffic_signals                                             signal
# 3557    traffic_signals                                             signal
# 3558    traffic_signals                                             signal
# 3559    traffic_signals                                             signal
# 3560    traffic_signals                                             signal
# 3561    traffic_signals                                             signal
# 3562    traffic_signals                                             signal
# 3563    traffic_signals                                             signal
# 3564    traffic_signals                                             signal
# 3565    traffic_signals                                             signal
# 3566    traffic_signals                                             signal
# 3567    traffic_signals                                             signal
# 3568    traffic_signals                                             signal
# 3569    traffic_signals                                             signal
# 3570    traffic_signals                                             signal
# 3571    traffic_signals                                             signal
# 3572    traffic_signals                                             signal
# 3573    traffic_signals                                             signal
# 3574    traffic_signals                                             signal
# 3575    traffic_signals                                             signal
# 3576    traffic_signals                                             signal
# 3577  turn_restrictions                                                 no
# 3578  turn_restrictions                                                 no
# 3579  turn_restrictions                                                 no
# 3580  turn_restrictions                                                 no
# 3581  turn_restrictions                                                 no
# 3582  turn_restrictions                                                 no
# 3583  turn_restrictions                                                 no
# 3584  turn_restrictions                                                 no
# 3585  turn_restrictions                                                 no
# 3586  turn_restrictions                                                 no
# 3587  turn_restrictions                                                 no
# 3588  turn_restrictions                                                 no
# 3589  turn_restrictions                                                 no
# 3590  turn_restrictions                                                 no
# 3591  turn_restrictions                                                 no
# 3592  turn_restrictions                                                 no
# 3593  turn_restrictions                                                 no
# 3594  turn_restrictions                                                 no
# 3595  turn_restrictions                                                 no
# 3596  turn_restrictions                                                 no
# 3597  turn_restrictions                                                 no
# 3598  turn_restrictions                                                 no
# 3599  turn_restrictions                                                 no
# 3600  turn_restrictions                                                 no
# 3601  turn_restrictions                                                 no
# 3602  turn_restrictions                                                 no
# 3603  turn_restrictions                                                 no
# 3604  turn_restrictions                                                 no
# 3605  turn_restrictions                                                 no
# 3606  turn_restrictions                                                 no
# 3607  turn_restrictions                                                 no
# 3608  turn_restrictions                                                 no
# 3609  turn_restrictions                                                 no
# 3610  turn_restrictions                                                 no
# 3611  turn_restrictions                                                 no
# 3612  turn_restrictions                                                 no
# 3613  turn_restrictions                                                 no
# 3614  turn_restrictions                                                 no
# 3615  turn_restrictions                                                 no
# 3616  turn_restrictions                                                 no
# 3617  turn_restrictions                                                 no
# 3618  turn_restrictions                                                 no
# 3619  turn_restrictions                                                 no
# 3620  turn_restrictions                                                 no
# 3621  turn_restrictions                                                 no
# 3622  turn_restrictions                                                 no
# 3623  turn_restrictions                                                 no
# 3624  turn_restrictions                                                 no
# 3625  turn_restrictions                                                 no
# 3626  turn_restrictions                                                 no
# 3627  turn_restrictions                                                 no
# 3628  turn_restrictions                                                 no
# 3629  turn_restrictions                                                 no
# 3630  turn_restrictions                                                 no
# 3631  turn_restrictions                                                 no
# 3632  turn_restrictions                                                 no
# 3633  turn_restrictions                                                 no
# 3634  turn_restrictions                                                 no
# 3635  turn_restrictions                                                 no
# 3636  turn_restrictions                                                 no
# 3637  turn_restrictions                                                 no
# 3638  turn_restrictions                                                 no
# 3639  turn_restrictions                                                 no
# 3640  turn_restrictions                                                 no
# 3641  turn_restrictions                                                 no
# 3642  turn_restrictions                                                 no
# 3643  turn_restrictions                                                 no
# 3644  turn_restrictions                                                 no
# 3645  turn_restrictions                                                 no
# 3646  turn_restrictions                                                 no
# 3647  turn_restrictions                                                 no
# 3648  turn_restrictions                                                 no
# 3649  turn_restrictions                                                 no
# 3650  turn_restrictions                                                 no
# 3651  turn_restrictions                                                 no
# 3652  turn_restrictions                                                 no
# 3653  turn_restrictions                                                 no
# 3654  turn_restrictions                                                 no
# 3655  turn_restrictions                                                 no
# 3656  turn_restrictions                                                 no
# 3657  turn_restrictions                                                 no
# 3658  turn_restrictions                                                 no
# 3659  turn_restrictions                                                 no
# 3660  turn_restrictions                                                 no
# 3661  turn_restrictions                                                 no
# 3662  turn_restrictions                                                 no
# 3663  turn_restrictions                                                 no
# 3664  turn_restrictions                                                 no
# 3665  turn_restrictions                                                 no
# 3666  turn_restrictions                                                 no
# 3667  turn_restrictions                                                 no
# 3668  turn_restrictions                                                 no
# 3669  turn_restrictions                                                 no
# 3670  turn_restrictions                                                 no
# 3671  turn_restrictions                                                 no
# 3672  turn_restrictions                                                 no
# 3673  turn_restrictions                                                 no
# 3674  turn_restrictions                                                 no
# 3675  turn_restrictions                                                 no
# 3676  turn_restrictions                                                 no
# 3677  turn_restrictions                                                 no
# 3678  turn_restrictions                                                 no
# 3679  turn_restrictions                                                 no
# 3680  turn_restrictions                                                 no
# 3681  turn_restrictions                                                 no
# 3682  turn_restrictions                                                 no
# 3683  turn_restrictions                                                 no
# 3684  turn_restrictions                                                 no
# 3685  turn_restrictions                                                 no
# 3686  turn_restrictions                                                 no
# 3687  turn_restrictions                                                 no
# 3688  turn_restrictions                                                 no
# 3689  turn_restrictions                                                 no
# 3690  turn_restrictions                                                 no
# 3691  turn_restrictions                                                 no
# 3692  turn_restrictions                                                 no
# 3693  turn_restrictions                                                 no
# 3694  turn_restrictions                                                 no
# 3695  turn_restrictions                                                 no
# 3696  turn_restrictions                                                 no
# 3697  turn_restrictions                                                 no
# 3698  turn_restrictions                                                 no
# 3699  turn_restrictions                                                 no
# 3700  turn_restrictions                                                 no
# 3701  turn_restrictions                                                 no
# 3702  turn_restrictions                                                 no
# 3703  turn_restrictions                                                 no
# 3704  turn_restrictions                                                 no
# 3705  turn_restrictions                                                 no
# 3706  turn_restrictions                                                 no
# 3707  turn_restrictions                                                 no
# 3708  turn_restrictions                                                 no
# 3709  turn_restrictions                                                 no
# 3710  turn_restrictions                                                 no
# 3711  turn_restrictions                                                 no
# 3712  turn_restrictions                                                 no
# 3713  turn_restrictions                                                 no
# 3714  turn_restrictions                                                 no
# 3715  turn_restrictions                                                 no
# 3716  turn_restrictions                                                 no
# 3717  turn_restrictions                                                 no
# 3718  turn_restrictions                                                 no
# 3719  turn_restrictions                                                 no
# 3720  turn_restrictions                                                yes
# 3721  turn_restrictions                                                yes
# 3722  turn_restrictions                                                yes
# 3723  turn_restrictions                                                yes
# 3724  turn_restrictions                                                yes
# 3725  turn_restrictions                                                yes
# 3726  turn_restrictions                                                yes
# 3727  turn_restrictions                                                yes
# 3728  turn_restrictions                                                yes
# 3729  turn_restrictions                                                yes
# 3730  turn_restrictions                                                yes
# 3731  turn_restrictions                                                yes
# 3732  turn_restrictions                                                yes
# 3733  turn_restrictions                                                yes
# 3734  turn_restrictions                                                yes
# 3735  turn_restrictions                                                yes
# 3736              usage                                               main
# 3737              usage                                               main
# 3738              usage                                               main
# 3739              usage                                               main
# 3740              usage                                               main
# 3741              usage                                               main

# %% [markdown]
# Well, that was wholly unsatisfying.
#
# Below is a second method to get at the coffee shops on streets that have been designated as bike paths.
#
# This probably isn't the _best_ way to achieve the objective of isolating cafes accessible by bike routes since a given street may have some stretches with bike lanes and other parts without.

# %%
# Queries to find coffee shops on bike paths
cycleways_info = 'SELECT DISTINCT cycleway_ids.*, value AS "Street" FROM ({}) cycleway_ids LEFT JOIN ways_tags ON ways_tags.id == cycleway_ids.ways_id WHERE key == "name"'.format(cycleway_ids.strip('\n'))
cafes_info = 'SELECT cafes.[Cafe Name], streets.value AS "Street" FROM (SELECT DISTINCT q1.id AS "id", q1.lat AS "Latitude", q1.lon AS "Longitude", q1.value AS "Cafe Name" FROM (SELECT nodes_tags.id, nodes.lat, nodes.lon, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "name") q1 JOIN (SELECT nodes_tags.id, nodes_tags.key, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "amenity" AND value == "cafe" ORDER BY value) q2 ON q1.id == q2.id WHERE q2.value == "cafe") cafes LEFT JOIN (SELECT nodes_tags.id, nodes.lat, nodes.lon, nodes_tags.value FROM nodes_tags LEFT JOIN nodes ON nodes_tags.id == nodes.id WHERE key == "street") streets ON cafes.id = streets.id'
final_query = 'SELECT cycleways_info.*, cafes.[Cafe Name] FROM ({}) cycleways_info LEFT JOIN ({}) cafes ON cycleways_info.Street == cafes.Street WHERE cafes.[Cafe Name] NOT NULL'.format(cycleways_info, cafes_info)

# Query to Pandas DataFrame
df = pd.read_sql_query(final_query, conn)
df
# Out:
#         ways_id                 Street                          Cafe Name
# 0       8915796          Fulton Street                          Starbucks
# 1       8916191        Mariposa Street                          Starbucks
# 2       8916792             7th Street                  Sightglass Coffee
# 1631  513963921  South Van Ness Avenue                  Flying Pig Bistro
# 1632  513968172        Harrison Street                     Epicenter Cafe
# 1633  513968173          Folsom Street               Anton's Pizza & Deli
# 1634  513968173          Folsom Street                El Capitan Taqueria
# 1635  513968173          Folsom Street            Sextant Coffee Roasters
# 1636  513968173          Folsom Street                        Stable Cafe
# 1637  514407369        Columbus Avenue                           Eight Am
# 1638  514407369        Columbus Avenue                        Happy Donut
# 1639  514407369        Columbus Avenue  Mario's Bohemian Cigar Store Cafe
# 1640  514442924            18th Street                           Farley's
# 1641  514442924            18th Street                   Starbucks Coffee
# 1642  514442927            18th Street                           Farley's
# 1643  514442927            18th Street                   Starbucks Coffee
# 1644  514461304            22nd Street             Mr & Mrs Miscellaneous
# 1645  514461306            22nd Street             Mr & Mrs Miscellaneous
# 1646  514479285            17th Street                             H Café
# 1647  514479285            17th Street                       Philz Coffee
# 1648  514479286            17th Street                             H Café
# 1649  514479286            17th Street                       Philz Coffee
# 1650  514605580             4th Street                    6 Flavor Coffee
# 1651  514605580             4th Street                     Tazza D’ Amore
# 1652  514606777             4th Street                    6 Flavor Coffee
# 1653  514606777             4th Street                     Tazza D’ Amore
# 1654  514608333          Phelan Avenue                 Chasing Lions Cafe
# 1655  515595963            Polk Street                         Basik Cafe
# 1656  515595963            Polk Street                        Common Sage
# 1657  515595963            Polk Street                              Crave
# 1658  515595963            Polk Street                    Fueling Station
# 1659  515595963            Polk Street                Peet's Coffee & Tea
# 1660  515595963            Polk Street                        Star Bagels
# 1661  515595963            Polk Street                           Teaspoon
# 1662  515595963            Polk Street                    The Crepe House
# 1663  516177129        Van Ness Avenue                        Boston Cafe
# 1664  516177129        Van Ness Avenue                          Starbucks
# 1665  516619534             4th Street                    6 Flavor Coffee
# 1666  516619534             4th Street                     Tazza D’ Amore
# 1667  516940742        Mariposa Street                          Starbucks
# 1668  517260065        Columbus Avenue                           Eight Am
# 1669  517260065        Columbus Avenue                        Happy Donut
# 1670  517260065        Columbus Avenue  Mario's Bohemian Cigar Store Cafe

# %% [markdown]
# Unfortunately, because I can't join on a _unique_ key, solving for internet access from this list is not feasibly reliably (i.e., I can only join on `Cafe Name`, which presumes a level of uniqueness among the names of cafes).

# %% [markdown]
# ## Suggestions (Improvement, Additional Analysis)
#
# Given the observations above, I think there are several potential improvement opportunities:
# - The schema above doesn't support look-ups of `nodes` via `ways_nodes` because the `ways_nodes` are often used to define the `way` itself.
#  - Part of this is how the data structured and interrelated: this is possible through the use of relation tags that could create _route_ overlays. The schema employed in this project doesn't capture `relations` which precludes this type of analysis.
# - While the OSM is a living, breathing document subject to change by any user, it does suffer from frictions in capturing data, especially given the ever-evolving nature of the underlying city! While the above exploration of cafés highlights one such aspect, I'm certain there are others.
#  - I wonder if integrations with other, _more popular_ geolocation-based apps (or apps that support geo-tagging) could help "fill the funnel" of data.
# - While the OSM Project doesn't restrict tag types, I think that the redundancies observed (e.g., multiple ways of tagging a house number) above might be reduced if tag types for the _most commonly_ used tags were standardized more (or across geographies in a given country).
